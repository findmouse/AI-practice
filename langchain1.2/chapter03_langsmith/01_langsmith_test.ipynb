# %% [markdown]
# 例1：

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# envファイル内の変数を環境変数として読み込む
# override=True：.envファイルを優先する
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = ChatDeepSeek(
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
    model_name="deepseek-v4-flash"
)

print(model.invoke("こんにちは"))
# Out:
# content='こんにちは！どうかされましたか？😊' additional_kwargs={'refusal': None, 'reasoning_content': 'We need answer in Japanese. Need maybe greeting. User says "こんにちは" = hello. Need respond friendly.'} response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 88, 'total_tokens': 129, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 26, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 88}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': '96c64713-0181-4985-89f3-858480094f73', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fbb78-bd6a-7240-99a4-9aac8856b928-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 88, 'output_tokens': 41, 'total_tokens': 129, 'input_token_details': {'cache_read': 0
# ...

# %% [markdown]
# 例2：

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv(override=True)

CLOSEAI_API_KEY=os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL=os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(model="deepseek-v4-flash",
                        model_provider="openai",
                        api_key=CLOSEAI_API_KEY,
                        base_url=CLOSEAI_BASE_URL)

print(model.invoke("こんにちは、一言で答えてください"))
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[2], line 15
#      11                         model_provider="openai",
#      12                         api_key=CLOSEAI_API_KEY,
#      13                         base_url=CLOSEAI_BASE_URL)
#      14
# ---> 15 print(model.invoke("こんにちは、一言で答えてください"))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
# ...

# %% [markdown]
# 例3：

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
from rich import print as rprint

# .envファイルから環境変数を読み込む
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 1. モデルを初期化
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0.2,
    max_tokens=500,
    # 調整可能なパラメータを指定
    configurable_fields=("model", "model_provider", "temperature", "max_tokens"),
)

# 2. config 辞書を準備
config = {
    "run_name": "joke_generation",  # LangSmithではこの実行が "joke_generation" として表示される
    "tags": ["my_tag1", "my_tag2"],  # 分類・検索しやすいようにタグを付ける
    "metadata": {
        "user_id": "shkstart",     # ユーザーIDを記録
        "session_id": "sess_123"   # セッションIDを記録
    },
    "configurable": {
        "model": "deepseek-v4-pro",  # モデルパラメータを設定
        "model_provider": "openai",  # モデルプロバイダーパラメータを設定
        "temperature": 0.7,  # 温度パラメータを設定
        "max_tokens": 1000  # 最大トークン数を設定
    }
}

# 3. モデルを呼び出し、configを渡す
response = model.invoke(
    "1 + 2 = ？",
    config=config
)

rprint(response)
# Out:
# AIMessage(
#     content='1 + 2 = 3',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 32,
#             'prompt_tokens': 11,
#             'total_tokens': 43,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 24,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 11
#         },
#         'model_provider': 'openai',
#         'model_name': 'deepseek-v4-pro',
#         'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402',
#         'id': '7b0bfc74-5708-4b13-9a2d-8439e3e55abb',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
# ...
