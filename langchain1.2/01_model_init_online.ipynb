# %% [markdown]
# 1.1 DeepSeek公式サイトのDeepSeekモデルを呼び出す

# %%
from langchain_community.chat_models import ChatZhipuAI, ChatTongyi
from langchain_deepseek import ChatDeepSeek
import os

from dotenv import load_dotenv
from langchain_openrouter import ChatOpenRouter

load_dotenv(override=True)
# Out:
# True

# %%
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
DEEPSEEK_MODEL = os.getenv("DEEPSEEK_MODEL")

llm_deepseek = ChatDeepSeek(
    model=DEEPSEEK_MODEL,
    api_key = DEEPSEEK_API_KEY,
    base_url = DEEPSEEK_BASE_URL,
)

response = llm_deepseek.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私は**DeepSeek**です。中国の深度求索（DeepSeek）社によって開発されたAIアシスタントです。\n\n私の特徴をいくつか紹介しますね：\n\n✨ **知識と能力**\n- 知識のカットオフは2025年5月まで\n- 純粋なテキストモデルで、ファイル読み込みやリンク先の内容も扱えます\n- 最大1Mトークンまでの長文処理が可能（「三体」三部作を一度に読み込めるくらい！）\n\n🛠️ **便利な機能**\n- Web検索や音声入力にも対応（アプリ版は公式アプリストアからダウンロード可能）\n- ファイル添付（画像、PDF、Word、Excel、PPTなど）から文字情報を抽出して読めます\n- 読める範囲であれば画像やリンク先の内容も理解します\n\n💰 **完全無料**\n- 今のところ完全無料でご利用いただけます！（有料化の噂はありますが、公式発表はありません）\n\n🎯 **私のスタイル**\n- 温かみがあり、丁寧で、細やかな対応を心がけています\n- 質問には真摯に、そしてできるだけ詳しくお答えします\n\n何かお手伝いできることがあれば、遠慮なく聞いてくださいね。どんな質問でも大歓迎です！😊' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户用日语说“请介绍一下你自己”。这是一个非常常见的开场问题。用户可能刚接触我，想了解我的基本身份和能力。\n\n我需要用日语友好、清晰地介绍自己。可以涵盖我的名称、创造者、知识截止日期、核心能力（如文本处理、文件支持、上下文长度）、免费性质、服务方式，并表达乐于提供帮助的意愿。\n\n想到了从问候开始，然后分块说明这些关键信息，最后以开放性问题结束，邀请用户进一步互动。可以用轻松愉快的语气和表情符号保持友好。'} response_metadata={'token_usage': {'completion_tokens': 431, 'prompt_tokens': 10, 'total_tokens': 441, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reaso
# ...

# %%
DEEPSEEK_MODEL = os.getenv("DEEPSEEK_MODEL")


llm_deepseek = ChatDeepSeek(
    model=DEEPSEEK_MODEL,
)

response = llm_deepseek.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私は **DeepSeek** です。中国の深度求索（DeepSeek）社によって開発された、純粋なテキストベースのAIアシスタントです。\n\n## 私の特徴\n- **知識の範囲**: 2025年5月までの情報を持っています\n- **対応能力**: 1Mトークンという超大規模なコンテキストを処理でき、一度に「三体」三部作のような長大なテキストも扱えます\n- **ファイル対応**: 画像、PDF、PowerPoint、Word、Excel、テキストファイルなどから文字情報を読み取れます（ただし、マルチモーダル認識は非対応です）\n- **音声**: Web版とアプリ版で音声入力が可能（アプリ版では音声出力にも対応）\n- **言語**: 多言語対応で、ユーザーの言語に合わせて応答します\n- **価格**: 完全無料！Web版でもアプリ版でも、今のところ課金の予定はありません\n\n## 私がお手伝いできること\n質問への回答、文章作成、プログラミングサポート、アイデア出し、学習のお手伝いなど、幅広い分野でサポートできます。専門的で細やかな対応を心がけていますので、どんなことでもお気軽にご相談ください！\n\n何かお手伝いできることはありますか？😊' additional_kwargs={'refusal': None, 'reasoning_content': 'ふむ、ユーザーが「あなた自身について紹介してください」と聞いてきたね。初めての質問で、私というアシスタントのことを知りたいんだな。シンプルだけど、誠実に自己紹介するのが良さそう。\n\nユーザーはおそらく、私がどんな存在なのか、何ができるのか、どんな風に助けられるのかを知りたいんだろう。だから、基本情報から具体的な機能まで、わかりやすく整理して伝えよう。でも堅苦しくならないように、少し親しみやすいトーンがいいかも。\n\nそうだな…まずは名前と会社名、それから「会話と情報提供が得意なアシスタント」という基本の役割。次に具体的な助けられることをリストにしてみよう。ファイル処理とか大容量コンテキストとか、便利な機能は強調したい。無料だっていうのも大事なポイントだよね。\n\n最後に「今なにかお困りですか？」って聞けば、自然に会話が続きそう。よし、これでシンプルでわかりや
# ...

# %%
from langchain_community.chat_models import ChatZhipuAI
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")
ZHIPUAI_MODEL = os.getenv("ZHIPUAI_MODEL")


llm_zhipu = ChatZhipuAI(
    model=ZHIPUAI_MODEL,
    api_key = ZHIPUAI_API_KEY,
    base_url = ZHIPUAI_BASE_URL,
)

response = llm_zhipu.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私はZ.aiによって開発されたGLM大規模言語モデルです。様々なテキストデータで訓練され、質問に答えたり、情報提供したり、創作のお手伝いをしたりすることができます。\n\n私は会話を通じて人々の役に立つことを目指していますが、個人的なデータを保存することはありません。幅広い話題についてお話しできますが、リアルタイムの情報には制限がある場合があります。\n\n他に何か知りたいことやお手伝いできることはありますか？' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 306, 'completion_tokens_details': {'reasoning_tokens': 180}, 'prompt_tokens': 11, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 317}, 'model_name': 'glm-5.1', 'finish_reason': 'stop'} id='lc_run--019fb4eb-b4fd-7210-817c-7f0fd56ced90-0' tool_calls=[] invalid_tool_calls=[]

# %%
DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
DASHSCOPE_MODEL = os.getenv("DASHSCOPE_MODEL")


llm_tongyi = ChatTongyi(
    model=DASHSCOPE_MODEL,
    api_key = DASHSCOPE_API_KEY,
)

response = llm_tongyi.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 10
#       6     model=DASHSCOPE_MODEL,
#       7     api_key = DASHSCOPE_API_KEY,
#       8 )
#       9
# ---> 10 response = llm_tongyi.invoke("あなた自身について紹介してください。")
#      11 print(response)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
# ...

# %%
from langchain_openai import ChatOpenAI

llm_deepseek = ChatOpenAI(
    model=DEEPSEEK_MODEL,
    api_key = DEEPSEEK_API_KEY,
    base_url = DEEPSEEK_BASE_URL,
)

response = llm_deepseek.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私はDeepSeekです。DeepSeek社によって開発されたAIアシスタントです。\n\n私の特徴をいくつか紹介します：\n\n✨ **完全無料**：どなたでも無料でご利用いただけます\n📚 **幅広い知識**：2025年5月までの知識を持っています\n📄 **ファイル処理**：テキストファイルや画像、PDF、Word、Excel、PPTなどを読み取れます\n🔗 **リンク読み取り**：URLからも内容を取得可能です\n💬 **長文対応**：最大100万トークンのコンテキストを処理できるので、長い会話や大きな文書も得意です\n🌐 **インターネット検索**：必要に応じてWeb検索も活用できます（手動で有効にする必要あり）\n\n目的は、あなたの質問に丁寧に答え、問題解決のお手伝いをすることです。日本語でのコミュニケーションもOKですので、気軽に何でも質問してくださいね！\n\nどんなことでお手伝いできますか？😊' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 329, 'prompt_tokens': 10, 'total_tokens': 339, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 90, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '2c3ac3b3-228
# ...

# %% [markdown]
# # 中継プラットフォームを使用する

# %%
from langchain_openrouter import ChatOpenRouter
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")
ZHIPUAI_MODEL = os.getenv("ZHIPUAI_MODEL")


llm_zhipu = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key = OPENROUTER_API_KEY,
    base_url = OPENROUTER_API_BASE,
)

response = llm_zhipu.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私はDeepSeek（ディープシーク）です。深度求索（DeepSeek）社が開発した、最新世代の大規模言語モデルAIアシスタントです。\n\n**私の特徴：**\n- **知識カットオフ日**：2025年5月\n- **対応言語**：日本語をはじめ、多言語に対応。あなたの質問には日本語でお答えします\n- **機能**：\n  - テキストベースの対話（質問回答、文章作成、翻訳、要約など）\n  - ファイルアップロード対応（画像、PDF、Word、Excel、PPT、TXTなどからテキスト情報を読み取り）\n  - リンク先の読み取りが可能\n  - Web検索機能（手動でオンにする必要があります）\n  - 100万トークンのコンテキストウィンドウ（「海よりも深い」と例えられるほど大量の情報を一度に処理できます！）\n\n**できないこと：**\n- 画像の生成や認識（マルチモーダル機能はテキスト抽出のみ）\n- リアルタイム情報の自動取得（検索機能を有効にした場合のみ可能）\n\n私は無料でご利用いただけます。あなたの質問やお困りごとに、丁寧かつ誠実にお答えします。何かお手伝いできることはありますか？😊' additional_kwargs={} response_metadata={'model_name': 'deepseek/deepseek-v4-flash', 'id': 'gen-1785446807-s19qyZ7UPf25Gcbrqnxm', 'created': 1785446807, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--019fb4ec-3f80-7360-909f-77dbe1ae9d41-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 314, 'total_tokens': 324, 'input_token_details': {'cache_read': 0, 'cach
# ...

# %%
from langchain_openrouter import ChatOpenRouter
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")
ZHIPUAI_MODEL = os.getenv("ZHIPUAI_MODEL")


llm_zhipu = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    api_key = OPENROUTER_API_KEY,
    base_url = OPENROUTER_API_BASE,
)

response = llm_zhipu.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='私はAI言語モデルで、さまざまな質問に応じて情報を提供したり、会話をしたりするために設計されています。日本語を含む多くの言語でコミュニケーションを取ることができ、さまざまなトピックについての知識を持っています。文章作成、情報検索、アイデアの提案などをお手伝いすることができますので、何か聞きたいことや相談したいことがあれば、ぜひ教えてください！' additional_kwargs={} response_metadata={'model_name': 'openai/gpt-4o-mini', 'id': 'gen-1785446836-cOqGpdHKkBbKQtqdOtBi', 'created': 1785446836, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'system_fingerprint': 'fp_27599ce29d'} id='lc_run--019fb4ec-b37f-7621-9a48-35527b141e36-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 120, 'total_tokens': 133, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}

# %%
from langchain_openai import ChatOpenAI

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")
DEEPSEEK_MODEL = os.getenv("DEEPSEEK_MODEL")

llm_deepseek = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

response = llm_deepseek.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[10], line 13
#       9     api_key=CLOSEAI_API_KEY,
#      10     base_url=CLOSEAI_BASE_URL,
#      11 )
#      12
# ---> 13 response = llm_deepseek.invoke("あなた自身について紹介してください。")
#      14 print(response)
#      15
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
# ...

# %%
from langchain.chat_models import init_chat_model
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")


llm_deepseek = init_chat_model(
    "deepseek-v4-flash",
    api_key = DEEPSEEK_API_KEY
)

response = llm_deepseek.invoke("あなた自身について紹介してください。")
print(response)
# Out:
# content='こんにちは！私はDeepSeek、深度求索（DeepSeek）という会社が開発したAIアシスタントです。私の主な特徴をご紹介しますね：\n\n**基本情報**\n- **開発元**：深度求索（DeepSeek）\n- **モデル**：DeepSeek最新版\n- **知識カットオフ日**：2025年5月\n\n**できること**\n- 📝 **テキストでの会話**：質問に答えたり、文章作成のお手伝い\n- 📄 **ファイル処理**：画像、PDF、Word、Excel、PowerPoint、TXTファイルの内容を読み取り・分析（ただし、画像の視覚認識はできません）\n- 🔗 **リンク読み取り**：ウェブリンクの内容を解析可能\n- 🌐 **Web検索**：ユーザーが手動でオンにすると、最新情報を検索（Web/Appで利用可能）\n- 🎤 **音声入力**：Appでは音声での入力もサポート\n\n**性能**\n- **コンテキスト長**：1Mトークン（『三体』三部作を一度に処理できるほどの大容量）\n- **無料**：現在も完全無料でご利用いただけます\n- **多言語対応**：もちろん日本語もバッチリ！\n\n**使える環境**\n- Webブラウザ\n- スマートフォンアプリ（公式ストアからダウンロード）\n\n何かお手伝いできることがあれば、遠慮なくお聞きくださいね！😊' additional_kwargs={'refusal': None, 'reasoning_content': 'はい、これは自己紹介を求めている質問ですね。ユーザーは「あなた自身について紹介してください」と日本語で尋ねているので、私はAIアシスタントとしての基本的な情報を簡潔に伝える必要があります。\n\nまず、自分の名前や開発元を明確に示します。DeepSeekという名前で、深度求索（DeepSeek）という会社が開発したと説明すれば良いでしょう。次に、主要な機能や特徴を挙げます。テキストベースの会話が可能で、長いコンテキスト（1Mトークン）を処理できること、ファイル対応やWeb検索機能があること、無料で利用可能であること、そして多言語対応であることを簡潔に伝えます。\n\n最後に、ユーザーに質問を促すようなフレンドリーな締めくくりを加えると良いでしょう。これで自
# ...
