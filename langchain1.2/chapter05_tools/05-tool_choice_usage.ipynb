# %% [markdown]
# # tool_choice の使用
#
# ## 1、tool_choice の値が none の場合

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

# .envファイルから環境変数を読み込む
load_dotenv(override=True)

from langchain.chat_models import init_chat_model
import os

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

model = init_chat_model(
    model="openai/gpt-4o-mini",
    model_provider="openai",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

# %%
from langchain.tools import tool
from rich import print

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather],tool_choice="none")

response = model_with_tools.invoke("北京の今日の天気はどうですか？")
print(response)
# Out:
# AIMessage(
#     content='少々お待ちください。北京の今日の天気を調べます。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 18,
#             'prompt_tokens': 62,
#             'total_tokens': 80,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 2.01e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 2.01e-05,
#                 'upstream_inference_prompt_cost': 9.3e-06,
#                 'upstream_inference_completions_cost': 1.08e-05
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_4cd46a3bc2',
#         'id': 'gen-1785656924-5TQWczZNdH3dT7UyUJRl',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-530d-7860-84bf-3947a0aca6d0-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 62,
#         'output_tokens': 18,
#         'total_tokens': 80,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %% [markdown]
# ## 2、tool_choice の値が auto の場合

# %%
from langchain.tools import tool
from rich import print

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather],tool_choice="auto")

response = model_with_tools.invoke("北京の今日の天気はどうですか？")
# response = model_with_tools.invoke("2 + 3 = ?")
print(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 14,
#             'prompt_tokens': 61,
#             'total_tokens': 75,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 1.755e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 1.755e-05,
#                 'upstream_inference_prompt_cost': 9.15e-06,
#                 'upstream_inference_completions_cost': 8.4e-06
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_4cd46a3bc2',
#         'id': 'gen-1785656928-WdFqncWWL8zSy0am6jcW',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-6294-7773-b86c-56e121411799-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_LdZB8srp8qhSIy40EQbgypSq',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 61,
#         'output_tokens': 14,
#         'total_tokens': 75,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %% [markdown]
# ## 3、tool_choice の値が required の場合

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("北京の今日の天気はどうですか？")
print(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 14,
#             'prompt_tokens': 61,
#             'total_tokens': 75,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 1.755e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 1.755e-05,
#                 'upstream_inference_prompt_cost': 9.15e-06,
#                 'upstream_inference_completions_cost': 8.4e-06
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_4cd46a3bc2',
#         'id': 'gen-1785656931-QBj14vi8v2jotXxRfTGU',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-7168-7730-9de7-353b37aaa522-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_rX9eU1Bx77Qeeut5RwKelWS5',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 61,
#         'output_tokens': 14,
#         'total_tokens': 75,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 14,
#             'prompt_tokens': 56,
#             'total_tokens': 70,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 1.68e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 1.68e-05,
#                 'upstream_inference_prompt_cost': 8.4e-06,
#                 'upstream_inference_completions_cost': 8.4e-06
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_4cd46a3bc2',
#         'id': 'gen-1785656933-hsG6fZc4tz2AKcXx4PSW',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-7859-7711-965a-3327ca990e3e-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': 'Tokyo'},
#             'id': 'call_XpNZlB1zpmPdOkodqDiYPbdH',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 56,
#         'output_tokens': 14,
#         'total_tokens': 70,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %% [markdown]
# ## 4、指定したツールを強制的に呼び出す

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather1,get_weather2],tool_choice="get_weather2")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 5,
#             'prompt_tokens': 95,
#             'total_tokens': 100,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 1.725e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 1.725e-05,
#                 'upstream_inference_prompt_cost': 1.425e-05,
#                 'upstream_inference_completions_cost': 3e-06
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_c881474fd1',
#         'id': 'gen-1785656936-GXEVMIFb4OlEEuLrRM9n',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-8433-72b1-a273-eaaa216882b4-0',
#     tool_calls=[
#         {
#             'name': 'get_weather2',
#             'args': {'city': 'Tokyo'},
#             'id': 'call_aEyjNOdNaGd5e03IuIXXjD8C',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 95,
#         'output_tokens': 5,
#         'total_tokens': 100,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    当日の天気を取得する

    Args:
        city: 都市名
    """
    return f'{city}は本日晴れです'


model_with_tools = model.bind_tools([get_weather1,get_weather2],tool_choice="get_weather1")

response = model_with_tools.invoke("北京の今日の天気はどうですか？")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 5,
#             'prompt_tokens': 100,
#             'total_tokens': 105,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': None,
#                 'image_tokens': 0
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': 0,
#                 'cached_tokens': 0,
#                 'cache_write_tokens': 0,
#                 'video_tokens': 0
#             },
#             'cost': 1.8e-05,
#             'is_byok': False,
#             'cost_details': {
#                 'upstream_inference_cost': 1.8e-05,
#                 'upstream_inference_prompt_cost': 1.5e-05,
#                 'upstream_inference_completions_cost': 3e-06
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'openai/gpt-4o-mini',
#         'system_fingerprint': 'fp_c881474fd1',
#         'id': 'gen-1785656938-tmmSK9yKClJZ01Yaa252',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fc172-8a0c-7a40-a4fa-572c262998da-0',
#     tool_calls=[
#         {
#             'name': 'get_weather1',
#             'args': {'city': '北京'},
#             'id': 'call_qL7gfsSlE8msPwzkqHMg0whT',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 100,
#         'output_tokens': 5,
#         'total_tokens': 105,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )
