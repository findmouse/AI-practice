# %% [markdown]
# ## ローカルのollamaにあるモデルを使用して初期化する

# %%
from langchain.chat_models import init_chat_model
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="qwen3:8b",
    base_url="http://localhost:11434",
)
print(model.invoke("あなた自身について紹介してください。"))
# Out:
# content='こんにちは！私はQwen（通称：通義千問）と申します。アリババクラウドが開発した大規模言語モデルで、自然言語の理解と生成、質問への回答、さまざまなタスクの支援など、幅広い機能を持っています。私の技術は、Transformerアーキテクチャと深層学習に基づいており、膨大なトレーニングデータを基に学習しています。これにより、私は多様なトピックについての会話を楽しむことができ、ユーザーが求める情報を提供するためのサポートをします。\n\n私の主な役割は、ユーザーが持つ疑問や課題に対し、有益で親しみやすいアシスタントとしての役割を果たすこと。どんな質問でも、できるだけ丁寧に、正確に、そしてわかりやすくご案内します。お気軽にお話しください！何か特定のトピックや質問があれば、どんなことでもお気軽にどうぞ！' additional_kwargs={} response_metadata={'model': 'qwen3:8b', 'created_at': '2026-07-30T21:31:15.1060635Z', 'done': True, 'done_reason': 'stop', 'total_duration': 20927171000, 'load_duration': 13822311800, 'prompt_eval_count': 18, 'prompt_eval_duration': 215418000, 'eval_count': 465, 'eval_duration': 6876620000, 'logprobs': None, 'model_name': 'qwen3:8b', 'model_provider': 'ollama'} id='lc_run--019fb4ef-f370-7d92-afc1-d4abc7e92b28-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 465, 'total_tokens': 483}

# %% [markdown]
# ## init_chat_model()

# %%
from langchain_ollama import ChatOllama
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model_provider="ollama",
    model="qwen3:8b",
    base_url="http://localhost:11434",
)
# print(model.invoke("あなた自身について紹介してください。"))
result = model.invoke("あなた自身について紹介してください。")
print(result.content)
# Out:
# こんにちは！私はアリババグループ傘下の通義実験室が開発した大規模言語モデル「通義千問（Qwen）」です。私は多様なタスクをサポートできるように設計されており、質問への回答、コンテンツの作成、プログラミング、論理的推論、創造的な思考など、さまざまな分野でのサポートが可能です。英語、中国語、日本語など、複数の言語を扱うことができ、さまざまなシチュエーションに適応できます。私は膨大な量のテキストデータを学習し、その知識を基にユーザーの質問や要望に応じて情報を提供し、アシスタントとしての役割を果たします。何か質問やお手伝いが必要なことがございましたら、お気軽にお尋ねください！
