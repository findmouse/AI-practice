# %%
from rich import print
# left: 開始位置から現在のノードの位置までマージされた値
# right: 現在のノードの値
# 戻り値: マージ後の値
def my_reducer(left: list[str],right: list[str]) -> list[str]:
    return left + right
# 1. node1 実行後の値
left = ["start","node_1 の実行が完了しました"]
right = ["node_2 の実行が完了しました"]
# 2. マージ
merged = my_reducer(left,right)
print(merged)
# Out:
# ['start', 'node_1 の実行が完了しました', 'node_2 の実行が完了しました']
